# %%
import numpy as np
from matplotlib import pyplot as plt
from skimage import img_as_float, img_as_ubyte
from skimage import io
from scipy import ndimage as nd
from skimage.restoration import denoise_nl_means, estimate_sigma
from skimage.color import rgb2gray




img = img_as_float(io.imread("ng.jpg"))
img = rgb2gray(img)  # Convert to grayscale

sigma_est = np.mean(estimate_sigma(img))
nlm = denoise_nl_means(img, h=1.15 * sigma_est, fast_mode=True, patch_size=5, patch_distance=3)
nlmu = img_as_ubyte(nlm)

plt.imshow(nlm, cmap='gray')
plt.show()

#plt.hist(nlmu.flat, bins =1000, range= (0,255) )

seg1 = (nlmu <= 150)
seg2 = (nlmu > 150) &  (nlmu <= 200)
seg3 = (nlmu > 200)

alls = np.zeros((nlmu.shape[0], nlmu.shape[1], 3))

alls[seg1] = (1,0,0)
alls[seg1] = (0,1,0)
alls[seg1] = (0,0,1)

plt.imshow(alls)
# Out:
# C:\Users\R\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 12
#       6 from skimage.restoration import denoise_nl_means, estimate_sigma
#       7 from skimage.color import rgb2gray
# ---> 12 img = img_as_float(io.imread("ng.jpg"))
#      13 img = rgb2gray(img)  # Convert to grayscale
#      15 sigma_est = np.mean(estimate_sigma(img))
#
# File ~\anaconda3\Lib\site-packages\skimage\io\_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~\anaconda3\Lib\site-packages\skimage\io\manage_plugins.py:205, in call_plugin(kind, *args, **kwargs)
#     202     except IndexError:
#     203         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 205 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\skimage\io\_plugins\imageio_plugin.py:15, in imread(*args, **kwargs)
#      13 @wraps(imageio_imread)
#      14 def imread(*args, **kwargs):
# ---> 15     return np.asarray(imageio_imread(*args, **kwargs))
#
# File ~\anaconda3\Lib\site-packages\imageio\v2.py:226, in imread(uri, format, **kwargs)
#     223 imopen_args = decypher_format_arg(format)
#     224 imopen_args["legacy_mode"] = True
# --> 226 with imopen(uri, "ri", **imopen_args) as file:
#     227     result = file.read(index=0, **kwargs)
#     229 return result
#
# File ~\anaconda3\Lib\site-packages\imageio\core\imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~\anaconda3\Lib\site-packages\imageio\core\request.py:247, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     244     raise ValueError(f"Invalid Request.Mode: {mode}")
#     246 # Parse what was given
# --> 247 self._parse_uri(uri)
#     249 # Set extension
#     250 if extension is not None:
#
# File ~\anaconda3\Lib\site-packages\imageio\core\request.py:407, in Request._parse_uri(self, uri)
#     404 if is_read_request:
#     405     # Reading: check that the file exists (but is allowed a dir)
#     406     if not os.path.exists(fn):
# --> 407         raise FileNotFoundError("No such file: '%s'" % fn)
#     408 else:
#     409     # Writing: check that the directory to write to does exist
#     410     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: 'C:\Users\R\Desktop\New folder\a\ng.jpg'

# %%
import numpy as np
from matplotlib import pyplot as plt
from skimage import img_as_float, img_as_ubyte
from skimage import io
from scipy import ndimage as nd
from skimage.restoration import denoise_nl_means, estimate_sigma
from skimage.color import rgb2gray
from numpy import ones




img = img_as_float(io.imread("ng.jpg"))
img = rgb2gray(img_as_float(img)  # Convert to grayscale

sigma_est = np.mean(estimate_sigma(img))
nlm = denoise_nl_means(img, h=1.15 * sigma_est, fast_mode=True, patch_size=5, patch_distance=3)
nlmu = img_as_ubyte(nlm)
print(nlm.dtype)
print(nlmu.dtype)
plt.imshow(nlm, cmap='gray')
plt.show()

#plt.hist(nlmu.flat, bins =1000, range= (0,255) )

seg1 = (nlmu <= 200)
seg2 = (nlmu > 100) &  (nlmu <= 150)
seg3 = (nlmu > 150)




alls = np.zeros((nlmu.shape[0], nlmu.shape[1], 3))

alls[seg1] = (1,0,0)
alls[seg2] = (0,1,0)
alls[seg3] = (0,0,1)

plt.imshow(alls)

plt.show()
'''
seg1_open = nd.binary_opening (seg1, ones((3,3)))
seg1_close = nd.binary_closing (seg1_open, ones((3,3)))

seg2_open = nd.binary_opening (seg2, ones((3,3)))
seg2_close = nd.binary_closing (seg2_open, ones((3,3)))

seg3_open = nd.binary_opening (seg3, ones((3,3)))
seg3_close = nd.binary_closing (seg3_open, ones((3,3)))

allsc = np.zeros((nlmu.shape[0], nlmu.shape[1], 3))
allsc[seg1_close] = (1,0,0)
allsc[seg2_close] = (0,1,0)
allsc[seg3_close] = (0,0,1)
plt.imshow(allsc)
plt.show()

'''
# Out:
# float64
# uint8
# '\nseg1_open = nd.binary_opening (seg1, ones((3,3)))\nseg1_close = nd.binary_closing (seg1_open, ones((3,3)))\n\nseg2_open = nd.binary_opening (seg2, ones((3,3)))\nseg2_close = nd.binary_closing (seg2_open, ones((3,3)))\n\nseg3_open = nd.binary_opening (seg3, ones((3,3)))\nseg3_close = nd.binary_closing (seg3_open, ones((3,3)))\n\nallsc = np.zeros((nlmu.shape[0], nlmu.shape[1], 3))\nallsc[seg1_close] = (1,0,0)\nallsc[seg2_close] = (0,1,0)\nallsc[seg3_close] = (0,0,1)\nplt.imshow(allsc)\nplt.show()\n\n'
